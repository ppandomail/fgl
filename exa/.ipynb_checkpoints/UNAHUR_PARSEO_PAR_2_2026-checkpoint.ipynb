# %% [markdown]
# # UNIVERSIDAD NACIONAL DE HURLINGHAM
# ## Inst. de Tecnología e Ingeniería
# ### PARSEO Y GENERACIÓN DE CÓDIGO
# #### Prof: Mag. Ing. Pablo Pandolfo
# #### Examen Parcial - Julio 2026

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# ## Conceptos básicos

# %% [markdown]
# 1. ¿Qué es un parser y cuál es su función dentro de un compilador?
# 1. ¿Qué diferencia hay entre análisis léxico y análisis sintáctico?
# 1. ¿Qué es una gramática libre de contexto?
# 1. ¿Qué son los terminales y los no terminales?
# 1. ¿Qué es una producción?
# 1. ¿Qué es el símbolo inicial?
# 1. ¿Qué significa que una cadena pertenezca al lenguaje generado por una gramática?
# 1. ¿Qué es un árbol sintáctico?
# 1. ¿Qué diferencia hay entre un árbol sintáctico y una derivación?

# %% [markdown]
# ## LL(1)

# %% [markdown]
# 1. ¿Qué significa LL(1)?
# 1. ¿Qué condición debe tener una GIC para ser LL(1)?
# 1. ¿Por qué se llama parser top-down?
# 1. ¿Qué es una derivación por izquierda?
# 1. ¿Qué representa el lookahead?
# 1. ¿Por qué alcanza un solo símbolo de lookahead en LL(1)?
# 1. ¿Qué es FIRST?
# 1. ¿Cómo se calcula FIRST?
# 1. ¿Qué es FOLLOW?
# 1. ¿Cómo se calcula FOLLOW?
# 1. ¿Para qué sirven FIRST y FOLLOW?
# 1. ¿Cómo se construye una tabla LL(1)?
# 1. ¿Qué significa que una celda tenga dos producciones?
# 1. ¿Cómo detectás que una gramática no es LL(1)?
# 1. ¿Por qué la recursión izquierda genera problemas?
# 1. ¿Cómo se elimina la recursión izquierda?
# 1. ¿Qué es la factorización por izquierda?
# 1. ¿Cuándo es necesario factorizar?
# 1. ¿Qué pasa si una producción deriva ε?
# 1. ¿Cómo interviene FOLLOW cuando aparece ε?
# 1. ¿Qué ventajas tiene LL(1)?
# 1. ¿Qué limitaciones tiene?

# %% [markdown]
# ## SLR

# %% [markdown]
# 1. ¿Qué significa SLR?
# 1. ¿Qué significa LR?
# 1. ¿Qué diferencia hay entre top-down y bottom-up?
# 1. ¿Qué significa hacer una derivación derecha en orden inverso?
# 1. ¿Qué es un parser Shift-Reduce?
# 1. ¿Qué operaciones realiza un parser SLR?
# 1. ¿Qué es SHIFT?
# 1. ¿Qué es REDUCE?
# 1. ¿Qué es ACCEPT?
# 1. ¿Qué significa ERROR?
# 1. ¿Qué es la pila del parser?
# 1. ¿Qué contiene la pila?
# 1. ¿Qué información guarda un estado?
# 1. ¿Qué es un ítem LR(0)?
# 1. ¿Qué representa el punto (•) en un ítem?
# 1. ¿Qué es el cierre (closure)?
# 1. ¿Qué es la función GOTO?
# 1. ¿Cómo se construye el autómata LR(0)?
# 1. ¿Por qué se aumenta la gramática?
# 1. ¿Cuál es el objetivo de agregar S' → S?

# %% [markdown]
# ## Tabla SLR

# %% [markdown]
# 1. ¿Cómo se construye la tabla ACTION?
# 1. ¿Cómo se construye la tabla GOTO?
# 1. ¿Cuándo se agrega un SHIFT?
# 1. ¿Cuándo se agrega un REDUCE?
# 1. ¿Por qué FOLLOW se usa para colocar reducciones?
# 1. ¿Cuándo aparece ACCEPT?
# 1. ¿Qué significa una celda vacía?
# 1. ¿Cómo se usa la tabla durante el análisis?
# 1. ¿Qué es un conflicto Shift/Reduce?
# 1. ¿Qué es un conflicto Reduce/Reduce?
# 1. ¿Por qué aparecen esos conflictos?
# 1. ¿Puede una gramática ambigua generar conflictos?
# 1. ¿SLR resuelve todas las gramáticas LR?
# 1. ¿Qué diferencia hay entre SLR, LALR y LR(1)?

# %% [markdown]
# ## Comparaciones

# %% [markdown]
# 1. Compará LL(1) y SLR.
# 1. ¿Cuál reconoce un conjunto más grande de gramáticas?
# 1. ¿Cuál es más sencillo de implementar?
# 1. ¿Cuál utiliza FIRST y FOLLOW?
# 1. ¿Cuál utiliza ítems LR?
# 1. ¿Cuál trabaja desde la raíz hacia las hojas?
# 1. ¿Cuál construye el árbol desde las hojas hacia la raíz?
# 1. ¿Cuál acepta recursión izquierda?
# 1. ¿Cuál requiere transformar la gramática?

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# 1. Calcular FIRST de una gramática.
# 1. Calcular FOLLOW.
# 1. Construir una tabla LL(1).
# 1. Determinar si una gramática es LL(1).
# 1. Eliminar recursión izquierda.
# 1. Factorizar una gramática.
# 1. Simular el análisis LL(1) de una cadena.
# 1. Construir el conjunto de ítems LR(0).
# 1. Construir el autómata LR(0).
# 1. Construir la tabla SLR.
# 1. Simular paso a paso un análisis Shift-Reduce.
# 1. Encontrar conflictos en una tabla SLR.

# %% [markdown]
# ## Preguntas

# %% [markdown]
# 1. ¿Puede una gramática ser SLR pero no LL(1)? ¿Por qué?
# 1. ¿Toda gramática LL(1) es SLR? Explicá tu respuesta.
# 1. ¿Qué diferencia hay entre un parser predictivo recursivo y uno basado en tabla LL(1)?
# 1. ¿Por qué FIRST y FOLLOW no alcanzan para construir un parser SLR sin el autómata?
# 1. ¿Qué información adicional aporta el autómata LR(0)?
# 1. ¿Por qué el parser SLR reduce únicamente cuando el lookahead pertenece a FOLLOW?
# 1. ¿Qué sucede si dos producciones tienen el mismo FIRST?
# 1. ¿Qué ocurre si FIRST y FOLLOW se superponen cuando hay una producción que deriva ε?
