# %% [markdown]
# # UNIVERSIDAD NACIONAL DE HURLINGHAM
# ## Inst. de Tecnología e Ingeniería
# ### LENGUAJES FORMALES Y AUTÓMATAS
# #### Prof: Mag. Ing. Pablo Pandolfo
# #### Examen Final - Mayo 2026

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# #### NOTA: EL EXAMEN ESCRITO ES UN DOCUMENTO DE GRAN IMPORTANCIA PARA LA EVALUACIÓN DE LOS CONOCIMIENTOS ADQUIRIDOS, POR LO TANTO, SE SOLICITA LEER ATENTAMENTE LO SIGUIENTE
#
# * Responda claramente cada punto, detallando con la mayor precisión posible lo solicitado.
# * Sea prolijo y ordenado en el desarrollo de los temas.
# * Sea cuidadoso con las faltas de ortografía y sus oraciones.
# * No desarrollar el examen en lápiz.
# * Aprobación del examen: Con nota mayor o igual a 4 (cuatro)
# * Condiciones de aprobación: 60%
# * Duración de examen: 2,5 horas.

# %% [markdown]
# 1. $(((ab)^*)^* \mid \lambda)$ es equivalente a
#     * a) $(a^*b^*))^*$
#     * b) $(a^* \mid b^*)$

# %% [markdown]
# 2. $L = \{1^{2n} 2 3^m / n>=0, m=n+1\}$ puede ser reconocido por AF

# %% [markdown]
# 3. $M = \{x / x \in \{b, c, d\}^* \land x = b^{2k} c^{3k} d^{k+1} \land 1<=k<=3 \}$ es de tipo 3 de la Clasificación de Chomsky

# %% [markdown]
# 4. El conjunto de los lenguajes reconocidos por una MT es mayor al conjunto de los lenguajes reconocidos por un AP

# %% [markdown]
# 5. Sean $L_1 = \{\lambda\}$, $L_2 = \{aa, ab, bb\}$, $L_3 = \{\lambda, aa, bb\}$ y $L_4 = \{\}$ , definidos sobre $\{a, b\}$. Marcar V o F:
#     * a) $L_1 \cup L_2 = \{aa, ab, bb\}$
#     * b) $L_1 \cap L_4 = \{\}$
#     * c) $L_2 \cap L_3 = \{aa, bb\}$
#     * d) $L_1 – L_3 = \{ \lambda \}$

# %% [markdown]
# 6. $L=\{0^{2n+1} 1^{3j} / n,j>=1\}$ es regular, con alfabeto $\{0,1\}$

# %% [markdown]
# 7. $L = \{\lambda\}$. ¿Es posible diseñar una ER?

# %% [markdown]
# 8. $(aaa)^* (bbb)^*$ corresponde a $L=\{a^{3j} b^{3j} / j>=0\}$

# %% [markdown]
# 9. El lenguaje de los identificadores de un lenguaje de programación puede ser aceptado por un AF

# %% [markdown]
# 10. Un AF es un modelo que solamente reconoce lenguajes finitos

# %% [markdown]
# 11. Las cadenas del lenguaje $L = \{0^i 1^i 0^i 1^i / 0 <= i <= 2\}$ pueden ser aceptadas por un AF

# %% [markdown]
# 12. Si puedo construir un AF que reconozca un lenguaje $L$, puedo construir un AF que reconozca $L^R$

# %% [markdown]
# 13. $L = \{a^{2n} c \lor a^{2m}b / n,m>=0\}$, puede ser reconocido por un AP y un AF

# %% [markdown]
# 14. $L = \{$Cadenas que tienen estructura $xx^{-1}$, donde $x \in \{0,1\}^+$. ¿Puedo diseñar una GIC para generar las cadenas de este lenguaje?

# %% [markdown]
# 15. Se tiene 2 GIC, $G_1$ y $G_2$ que generan los lenguajes $L_1$ y $L_2$ respectivamente. ¿Puede diseñar la GIC del lenguaje $L_1 \cup L_2$? ¿Cómo se diseñaría esa gramática?

# %% [markdown]
# 16. $G = <\{S,A\}, \{a,b\}, S, P>$, donde $P = \{S \rightarrow AA, A \rightarrow AAA, A \rightarrow a, A \rightarrow bA, A \rightarrow Ab\}$. Genera las cadenas $bbabaaba$ y $bbaab$

# %% [markdown]
# 17. $L = \{a^r b^s c^t d^u / r,s,t,u>=1 \land r+t=s+u \}$
#     * a) El lenguaje definido es de tipo 3 de la Clasificación de Chomsky
#     * b) El autómata de menor potencia que reconoce las cadenas del lenguaje es el AP
#     * c) Las cadenas del lenguaje pueden generarse con una GIC
#     * d) La cadena mínima del lenguaje es $abcd$

# %% [markdown]
# 18. Puedo escribir la sintaxis de todas las sentencias de un lenguaje de programación con una GIC

# %% [markdown]
# 19. El lenguaje natural es un lenguaje formal

# %% [markdown]
# 20. Dada la siguiente definición BNF:
# $$<expr> \rightarrow <expr><expr> +$$
# $$<expr> \rightarrow <expr><expr> *$$
# $$<expr> \rightarrow a$$
# $$<expr> \rightarrow b$$
# $$<expr> \rightarrow c$$
# la cadena $abc*+$ pertenece al lenguaje

# %% [markdown]
# 21. Dada la siguiente GIC:
# $$E \rightarrow EOE$$
# $$E \rightarrow id$$
# $$E \rightarrow cte$$
# $$O \rightarrow +$$
# $$O \rightarrow -$$
# $$O \rightarrow *$$
# $$O \rightarrow /$$
#
# * a) ¿De qué tipo es la gramática definida? Justifique
# * b) ¿Es ambigua? Justifique
# * c) Busque una hilera válida de 7 símbolos como mínimo y realice el árbol de derivación correspondiente
# * d) ¿Qué pasaría si implementa esta gramática en un compilador para las expresiones aritméticas? Justifique

# %% [markdown]
# 22. Si $L_1$ es un LR y $L_2$ es un LIC entonces $L_1 \cap L_2$ es LR

# %% [markdown]
# 23. Si $L = \{a\}$ , lenguaje de una cadena que tiene un solo símbolo, entonces L es regular

# %% [markdown]
# 24. $\Sigma = \{0, 1\}$, entonces $\Sigma^0 = \lambda$

# %% [markdown]
# 25. $\Sigma = \{0, 1\}$, $\Sigma^*$ es un lenguaje regular
