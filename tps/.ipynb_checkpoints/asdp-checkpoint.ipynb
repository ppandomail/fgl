# %% [markdown]
# # TP ASDP
# ---

# %% [markdown]
# ### Eliminar factores comunes por la izquierda

# %% [markdown]
# $$S \rightarrow aTbRba \mid aTbc$$
# $$T \rightarrow a \mid Ta$$
# $$R \rightarrow c \mid cRb$$

# %% [markdown]
# $$A \rightarrow aBcDe \mid CD$$
# $$A \rightarrow aBcDF$$
# $$A \rightarrow aBcDf$$
# $$C \rightarrow k$$
# $$D \rightarrow h$$
# $$F \rightarrow d$$

# %% [markdown]
# $$<if> \rightarrow if (<cond>) <sent> else <sent>$$
# $$<if> \rightarrow if (<cond>) <sent>$$

# %% [markdown]
# ### Eliminar recursividad a izquierda

# %% [markdown]
# $$<listaExp> \rightarrow <operando> \mid <listaExp> <operador> <operando>$$

# %% [markdown]
# $$E \rightarrow E+T \mid E-T \mid T \mid F$$
# $$T \rightarrow T*F \mid T/F \mid F$$
# $$F \rightarrow num \mid (E)$$

# %% [markdown]
# $$listaExp \rightarrow exp \mid listaExp ; exp$$
# $$exp \rightarrow termino \mid exp + termino$$
# $$termino \rightarrow factor \mid termino * factor$$
# $$factor \rightarrow num \mid (exp)$$

# %% [markdown]
# ### ASDP

# %% [markdown]
# Sea la siguiente GIC, comprobar si es LL(1) y si lo es, construir su tabla de análisis y verificar si la entrada siguiente es analizada correctamente: a b ( 0 ) a c a
#
# $S \rightarrow A \mid a$
#
# $A \rightarrow b \, ( \, E \, ) \, S \, L$
#
# $L \rightarrow c \, S \mid \lambda$
#
# $E \rightarrow 0 \mid 1$

# %% [markdown]
# | PRIM                     |
# | --                       |
# | PRIM(S) = {b, a}         |
# | PRIM(A) = {b}            |
# | PRIM(L)  = {c, λ}        |
# | PRIM(E) = {0, 1}         |
#
# | SIG                      |
# | --                       |
# | SIG(S) = {\$, c}         |
# | SIG(A) = {\$, c}         |
# | SIG(L) = {\$, c}         |
# | SIG(E) = {)}             |
#
# | PRED                     |
# | --                       |
# | PRED(S -> A) = {b}       |
# | PRED(S -> a) = {a}       |
# | PRED(A -> b(E)SL) = {b}  |
# | PRED(L -> cS) = {c}      |
# | PRED(L -> λ) = {\$, c}   |
# | PRED(E -> 0) = {0}       |
# | PRED(E -> 1) = {1}       |
#
# * No es LL(1)

# %% [markdown]
# Hacer lo mismo que en caso anterior y si no es LL(1) hacer las modificaciones pertinentes (si se puede) para convertirla en LL(1). Construir su tabla de análisis y verificar si la entrada siguiente es analizada correctamente: z and or y x
#
# $S \rightarrow S \, or \, Q \mid Q$
#
# $Q \rightarrow Q \, R \mid R$
#
# $R \rightarrow F \, and \mid x \mid y$
#
# $F \rightarrow z$

# %% [markdown]
# * No es LL(1) porque es recursiva por la izquierda
# * Se elimina recursividad por la izquierda ....
#
# $S \rightarrow QS’$
#
# $S’ \rightarrow orQS’$
#
# $S’ \rightarrow λ$
#
# $Q \rightarrow RQ’$
#
# $Q’ \rightarrow RQ’$
#
# $Q’ \rightarrow \lambda$
#
# $R \rightarrow Fand$
#
# $R \rightarrow x$
#
# $R \rightarrow y$
#
# $F \rightarrow z$
#
# | PRIM                         |
# | --                           |
# | PRIM(S) = {z, x, y}          |
# | PRIM(S’) = {or, λ}           |
# | PRIM(Q) = {z, x, y}          |
# | PRIM(Q’) = {z, x, y, λ}      |
# | PRIM(R) = {z, x, y}          |
# | PRIM(F) = {z}                |
#
# | SIG                          |
# | --                           |
# | SIG(S) = {\$}                |
# | SIG(S’) = {\$}               |
# | SIG(Q) = {or, \$}            |
# | SIG(Q’) = {or, \$}           |
# | SIG(R) = {z, x, y, or, \$}   |
# | SIG(F) = {and}               |
#
# | PRED                         |
# | --                           |
# | PRED(S -> QS’) = {z, x, y}   |
# | PRED(S’ -> orQS’) = {or}     |
# | PRED(S’ -> λ) = {\$}         |
# | PRED(Q -> RQ’) = {z, x, y}   |
# | PRED(Q’ -> RQ’) = {z, x, y}  |
# | PRED(Q’ -> λ) = {or, \$}     |
# | PRED(R -> Fand) = {z}        |
# | PRED(R -> x) = {x}           |
# | PRED(R -> y) = {y}           |
# | PRED(F -> z) = {z}           |
#
# * Es LL(1)
#
# |    | or          | and   | x         | y         | z         | \$      |
# | -- | --          | --    | --        | --        | --        | --      |
# | S  | error       | error | S -> QS'  | S -> QS'  | S -> QS'  | error   |
# | S' | S’ -> orQS’ | error | error     | error     | error     | S’ -> λ |
# | Q  | error       | error | Q -> RQ'  | Q -> RQ'  | Q -> RQ'  | error   |
# | Q' | Q' -> λ     | error | Q' -> RQ' | Q' -> RQ' | Q' -> RQ' | Q' -> λ |
# | R  | error       | error | R -> x    | R -> y    | R -> Fand | error   |
# | F  | error       | error | error     | error     | F -> z    | error   |
#
# | Pila           | Entrada         | Regla o Acción |
# | --             | --              | --             |
# | \$ S           | z and or y x \$ | S -> QS’       |
# | \$ S’ Q        | z and or y x \$ | Q -> RQ’       |
# | \$ S’ Q’ R     | z and or y x \$ | R -> Fand      |
# | \$ S’ Q’ and F | z and or y x \$ | F -> z         |
# | \$ S’ Q’ and z | z and or y x \$ | Emparejar(z)   |
# | \$ S’ Q’ and   | and or y x \$   | Emparejar(and) |
# | \$ S’ Q’       | or y x \$       | Q’ -> λ        |
# | \$ S’          | or y x \$       | S’ -> orQS’    |
# | \$ S’ Q or     | or y x \$       | Emparejar(or)  |
# | \$ S’ Q        | y x \$          | Q -> RQ’       |
# | \$ S’ Q’ R     | y x \$          | R -> y         |
# | \$ S’ Q’ y     | y x \$          | Emparejar(y)   |
# | \$ S’ Q’       | x \$            | Q’ -> RQ’      |
# | \$ S’ Q’ R     | x \$            | R -> x         |
# | \$ S’ Q’ x     | x \$            | Emparejar(x)   |
# | \$ S’ Q’       | \$              | Q’ -> λ        |
# | \$ S’          | \$              | S’ -> λ        |
# | \$             | \$              | Aceptar        |

# %% [markdown]
# $$A \rightarrow (A)A \mid \lambda$$

# %% [markdown]
# $$A \rightarrow BC$$
# $$B \rightarrow \lambda \mid m$$
# $$C \rightarrow \lambda \mid s$$

# %% [markdown]
# $$S \rightarrow ABc$$
# $$A \rightarrow a \mid \lambda$$
# $$B \rightarrow b \mid \lambda$$

# %% [markdown]
# $$S \rightarrow aBCd$$
# $$B \rightarrow bb$$
# $$C \rightarrow cc$$

# %% [markdown]
# $$S \rightarrow aBCd$$
# $$B \rightarrow bB \mid d$$
# $$C \rightarrow cc$$

# %% [markdown]
# $$S \rightarrow aBCd$$
# $$B \rightarrow CB \mid b$$
# $$C \rightarrow cc \mid \lambda$$

# %% [markdown]
# $$S \rightarrow if B then S \mid write B \mid id:= B$$
# $$B \rightarrow id = id \mid id <> id \mid true \mid false$$

# %% [markdown]
# $$S \rightarrow if S E \mid otro$$
# $$E \rightarrow else S end if \mid end if$$

# %% [markdown]
# $$A \rightarrow abB \mid Bb$$
# $$B \rightarrow b \mid c$$

# %% [markdown]
# $$A \rightarrow CD \mid aB$$
# $$B \rightarrow aCd \mid \lambda$$
# $$C \rightarrow dCd \mid a \mid \lambda \mid ae$$
# $$D \rightarrow a$$

# %% [markdown]
# $$S \rightarrow AD \mid aB$$
# $$B \rightarrow aC$$
# $$C \rightarrow dC \mid a \mid ae$$
# $$D \rightarrow bD \mid \lambda$$
# $$A \rightarrow a \mid \lambda$$

# %% [markdown]
# $$E \rightarrow E + T \mid T$$
# $$T \rightarrow T * F \mid F$$
# $$F \rightarrow num \mid (E)$$

# %% [markdown]
# $$A \rightarrow cbB \mid Bb \mid ab$$
# $$B \rightarrow a \mid b \mid c$$

# %% [markdown]
# $$A \rightarrow adB \mid Bd$$
# $$B \rightarrow d \mid c \mid e$$

# %% [markdown]
# $$T \rightarrow T + T \mid T * H \mid H$$
# $$H \rightarrow num \mid (T)$$

# %% [markdown]
# $$A \rightarrow C \mid BCd$$
# $$B \rightarrow a \mid c \mid d \mid \lambda \mid aB$$
# $$C \rightarrow d \mid \lambda \mid aC$$

# %% [markdown]
# $$LE \rightarrow fdt \mid E ; LE$$
# $$E \rightarrow T E’$$
# $$E’ \rightarrow + T E’ \mid \lambda$$
# $$T \rightarrow F T’$$
# $$T’ \rightarrow * F T’ \mid \lambda$$
# $$F \rightarrow n \mid ( E )$$

# %% [markdown]
# $$S \rightarrow cA$$
# $$A \rightarrow aB$$
# $$B \rightarrow b \mid \lambda$$

# %% [markdown]
# $$B \rightarrow DL$$
# $$D \rightarrow id ; D \mid \lambda$$
# $$L \rightarrow S ; L \mid \lambda$$
# $$S \rightarrow a + a$$

# %% [markdown]
# $$S \rightarrow (A)$$
# $$A \rightarrow CB$$
# $$B \rightarrow ;A \mid \lambda$$
# $$C \rightarrow x \mid S$$
